# %% [markdown]
# 棋盘坐标 E4, 转化为坐标形式就是 (3, 4), 坐标数值大小是从 0 开始，到 7 结束。
#
# Board 类中，提供以上两种坐标的转化方法：
# + `board_num(action)`: 棋盘坐标转化为数字坐标。
#     + action: 棋盘坐标，e.g. 'G6'
#     + 返回值: 数字坐标，e.g. (5, 6)
# + `num_board(action)`: 数字坐标转化为棋盘坐标。
#     + action: 数字坐标，e.g. (2, 7)
#     + 返回值: 棋盘坐标，e.g. 'H3'

# %% [markdown]
# # 2.2 创建随机玩家

# %%
# 导入随机包
import random

class RandomPlayer:
    """
    随机玩家, 随机返回一个合法落子位置
    """

    def __init__(self, color):
        """
        玩家初始化
        :param color: 下棋方，'X' - 黑棋，'O' - 白棋
        """
        self.color = color
        

    def random_choice(self, board):
        """
        从合法落子位置中随机选一个落子位置
        :param board: 棋盘
        :return: 随机合法落子位置, e.g. 'A1' 
        """
        # 用 list() 方法获取所有合法落子位置坐标列表
        action_list = list(board.get_legal_actions(self.color))

        # 如果 action_list 为空，则返回 None,否则从中选取一个随机元素，即合法的落子坐标
        if len(action_list) == 0:
            return None
        else:
            return random.choice(action_list)

    def get_move(self, board):
        """
        根据当前棋盘状态获取最佳落子位置
        :param board: 棋盘
        :return: action 最佳落子位置, e.g. 'A1'
        """
        if self.color == 'X':
            player_name = '黑棋'
        else:
            player_name = '白棋'
        print("请等一会，对方 {}-{} 正在思考中...".format(player_name, self.color))
        action = self.random_choice(board)
        return action

# %% [markdown]
# # 2.3 创建人类

# %%
class HumanPlayer:
    """
    人类玩家
    """

    def __init__(self, color):
        """
        玩家初始化
        :param color: 下棋方，'X' - 黑棋，'O' - 白棋
        """
        self.color = color
    

    def get_move(self, board):
        """
        根据当前棋盘输入人类合法落子位置
        :param board: 棋盘
        :return: 人类下棋落子位置
        """
        # 如果 self.color 是黑棋 "X",则 player 是 "黑棋"，否则是 "白棋"
        if self.color == "X":
            player = "黑棋"
        else:
            player = "白棋"

        # 人类玩家输入落子位置，如果输入 'Q', 则返回 'Q'并结束比赛。
        # 如果人类玩家输入棋盘位置，e.g. 'A1'，
        # 首先判断输入是否正确，然后再判断是否符合黑白棋规则的落子位置
        while True:
            action = input(
                    "请'{}-{}'方输入一个合法的坐标(e.g. 'D3'，若不想进行，请务必输入'Q'结束游戏。): ".format(player,
                                                                                 self.color))

            # 如果人类玩家输入 Q 则表示想结束比赛
            if action == "Q" or action == 'q':
                return "Q"
            else:
                row, col = action[1].upper(), action[0].upper()

                # 检查人类输入是否正确
                if row in '12345678' and col in 'ABCDEFGH':
                    # 检查人类输入是否为符合规则的可落子位置
                    if action in board.get_legal_actions(self.color):
                        return action
                else:
                    print("你的输入不合法，请重新输入!")

# %% [markdown]
# # 2.4 测试

# %%
# 导入黑白棋文件
from game import Game  
from alpha_one import *
from mcts import MctsPlayer

# 人类玩家黑棋初始化
black_player =  MctsPlayer("X")

# AI 玩家 白棋初始化
white_player = AlphaOne("O")

# 游戏初始化，第一个玩家是黑棋，第二个玩家是白棋
game = Game(black_player, white_player)

# 开始下棋
game.run()
# Out:
# =====开始游戏!=====
#
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . . . . . . .
# 3 . . . . . . . .
# 4 . . . O X . . .
# 5 . . . X O . . .
# 6 . . . . . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 2 / 0 / 0
# 白   棋: 2 / 0 / 0
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 1670	play out time: 0.04s	policy time: 0.04s	total time: 59s 27.9ms
# play out times: 1670	avg play out time: 0s 35.3ms	avg policy time: 0.03s
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . . . . . . .
# 3 . . . . . . . .
# 4 . . . O X . . .
# 5 . . . X X X . .
# 6 . . . . . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 4 / 59 / 59
# 白   棋: 1 / 0 / 0
#
# 请等一会，对方 白棋-O 正在思考中...
# mcts 58.00328779220581
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . . . . . . .
# 3 . . . . . . . .
# 4 . . . O X . . .
# 5 . . . O X X . .
# 6 . . . O . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 3 / 59 / 59
# 白   棋: 3 / 58 / 58
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 1664	play out time: 0.04s	policy time: 0.04s	total time: 59s 20.2ms
# play out times: 1664	avg play out time: 0s 35.5ms	avg policy time: 0.04s
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . . . . . . .
# 3 . . . . . . . .
# 4 . . X X X . . .
# 5 . . . O X X . .
# 6 . . . O . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 5 / 59 / 118
# 白   棋: 2 / 58 / 58
#
# 请等一会，对方 白棋-O 正在思考中...
# mcts 58.00290513038635
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . . . . . . .
# 3 . . . . . . . .
# 4 . . X X X O . .
# 5 . . . O O X . .
# 6 . . . O . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 4 / 59 / 118
# 白   棋: 4 / 58 / 116
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 1679	play out time: 0.03s	policy time: 0.03s	total time: 59s 28.3ms
# play out times: 1679	avg play out time: 0s 35.2ms	avg policy time: 0.03s
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . . . . . . .
# 3 . . . . . X . .
# 4 . . X X X X . .
# 5 . . . O O X . .
# 6 . . . O . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 6 / 59 / 177
# 白   棋: 3 / 58 / 116
#
# 请等一会，对方 白棋-O 正在思考中...
# mcts 58.004101276397705
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . . . . . . .
# 3 . . . . O X . .
# 4 . . X X O X . .
# 5 . . . O O X . .
# 6 . . . O . . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 5 / 59 / 177
# 白   棋: 5 / 58 / 174
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 1714	play out time: 0.03s	policy time: 0.03s	total time: 59s 16.4ms
# play out times: 1714	avg play out time: 0s 34.4ms	avg policy time: 0.03s
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . . . . . . .
# 3 . . . . O X . .
# 4 . . X X O X . .
# 5 . . . X O X . .
# 6 . . . O X . . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 7 / 59 / 236
# 白   棋: 4 / 58 / 174
#
# 请等一会，对方 白棋-O 正在思考中...
# mcts 58.00235414505005
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . . . . . . .
# 3 . . . . O X . .
# 4 . . X X O X . .
# 5 . . . X O X . .
# 6 . . . O O O . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 6 / 59 / 236
# 白   棋: 6 / 58 / 232
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 1751	play out time: 0.04s	policy time: 0.04s	total time: 59s 17.2ms
# play out times: 1751	avg play out time: 0s 33.7ms	avg policy time: 0.03s
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . . . . . . .
# 3 . . . X X X . .
# 4 . . X X X X . .
# 5 . . . X O X . .
# 6 . . . O O O . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 9 / 59 / 295
# 白   棋: 4 / 58 / 232
#
# 请等一会，对方 白棋-O 正在思考中...
# mcts 58.00305724143982
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . . . . . . .
# 3 . . . X X X . .
# 4 . . X X X X . .
# 5 . . O O O X . .
# 6 . . . O O O . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 8 / 59 / 295
# 白   棋: 6 / 58 / 290
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 1817	play out time: 0.03s	policy time: 0.03s	total time: 59s 19.6ms
# play out times: 1817	avg play out time: 0s 32.5ms	avg policy time: 0.03s
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . . . . . . .
# 3 . . . X X X . .
# 4 . . X X X X . .
# 5 . . X O O X . .
# 6 . X . O O O . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 10 / 59 / 354
# 白   棋: 5 / 58 / 290
#
# 请等一会，对方 白棋-O 正在思考中...
# mcts 58.001391887664795
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . . . . . . .
# 3 . . O X X X . .
# 4 . . X O X X . .
# 5 . . X O O X . .
# 6 . X . O O O . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 9 / 59 / 354
# 白   棋: 7 / 58 / 348
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 1868	play out time: 0.03s	policy time: 0.03s	total time: 59s 18.3ms
# play out times: 1868	avg play out time: 0s 31.6ms	avg policy time: 0.03s
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . .
# 3 . . X X X X . .
# 4 . . X O X X . .
# 5 . . X O O X . .
# 6 . X . O O O . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 11 / 59 / 413
# 白   棋: 6 / 58 / 348
#
# 请等一会，对方 白棋-O 正在思考中...
# mcts 58.0036735534668
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . .
# 3 . . X X X X . .
# 4 . . X O X X . .
# 5 . O O O O X . .
# 6 . X . O O O . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 10 / 59 / 413
# 白   棋: 8 / 58 / 406
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 1931	play out time: 0.04s	policy time: 0.04s	total time: 59s 5.19ms
# play out times: 1931	avg play out time: 0s 30.6ms	avg policy time: 0.03s
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . .
# 3 . . X X X X . .
# 4 . . X O X X . .
# 5 . X O O O X . .
# 6 X X . O O O . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 12 / 59 / 472
# 白   棋: 7 / 58 / 406
#
# 请等一会，对方 白棋-O 正在思考中...
# mcts 58.002694845199585
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . .
# 3 . . X X X X . .
# 4 . . X O X X . .
# 5 . X O O O O O .
# 6 X X . O O O . .
# 7 . . . . . . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 11 / 59 / 472
# 白   棋: 9 / 58 / 464
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 2004	play out time: 0.03s	policy time: 0.03s	total time: 59s 0.522ms
# play out times: 2004	avg play out time: 0s 29.4ms	avg policy time: 0.03s
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . .
# 3 . . X X X X . .
# 4 . . X O X X . .
# 5 . X O O X O O .
# 6 X X . O X O . .
# 7 . . . . X . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 14 / 59 / 531
# 白   棋: 7 / 58 / 464
#
# 请等一会，对方 白棋-O 正在思考中...
# mcts 58.00223517417908
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . .
# 3 . . X X X X . .
# 4 . . X O O O O .
# 5 . X O O X O O .
# 6 X X . O X O . .
# 7 . . . . X . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 12 / 59 / 531
# 白   棋: 10 / 58 / 522
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 2066	play out time: 0.03s	policy time: 0.03s	total time: 59s 19.1ms
# play out times: 2066	avg play out time: 0s 28.6ms	avg policy time: 0.03s
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . .
# 3 . . X X X X . .
# 4 . . X O X O O .
# 5 . X O O X X O .
# 6 X X . O X X X .
# 7 . . . . X . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 16 / 59 / 590
# 白   棋: 7 / 58 / 522
#
# 请等一会，对方 白棋-O 正在思考中...
# mcts 58.0012571811676
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . .
# 3 . . X X X X . .
# 4 . . X O X O O .
# 5 . X O O X O O .
# 6 X X . O O X X .
# 7 . . . O X . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 14 / 59 / 590
# 白   棋: 10 / 58 / 580
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 2222	play out time: 0.02s	policy time: 0.02s	total time: 59s 17.6ms
# play out times: 2222	avg play out time: 0s 26.6ms	avg policy time: 0.03s
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . .
# 3 . . X X X X . .
# 4 . . X O X O O .
# 5 . X O O X O O .
# 6 X X . X O X X .
# 7 . . X X X . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 17 / 59 / 649
# 白   棋: 8 / 58 / 580
#
# 请等一会，对方 白棋-O 正在思考中...
# mcts 58.0038685798645
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . .
# 3 . . X X X X . .
# 4 . . X O X O O .
# 5 . X O O X O O .
# 6 X X O O O X X .
# 7 . . X X X . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 16 / 59 / 649
# 白   棋: 10 / 58 / 638
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 2422	play out time: 0.03s	policy time: 0.02s	total time: 59s 1.12ms
# play out times: 2422	avg play out time: 0s 24.4ms	avg policy time: 0.02s
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . .
# 3 . . X X X X X .
# 4 . . X O X X X .
# 5 . X O O X O X .
# 6 X X O O O X X .
# 7 . . X X X . . .
# 8 . . . . . . . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 20 / 59 / 708
# 白   棋: 7 / 58 / 638
#
# 请等一会，对方 白棋-O 正在思考中...
# mcts 58.00211191177368
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . .
# 3 . . X X X X X .
# 4 . . X O X X X .
# 5 . X O O X O X .
# 6 X X O O O X X .
# 7 . . X X O . . .
# 8 . . . . . O . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 19 / 59 / 708
# 白   棋: 9 / 58 / 696
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 2309	play out time: 0.02s	policy time: 0.02s	total time: 59s 0.431ms
# play out times: 2309	avg play out time: 0s 25.6ms	avg policy time: 0.03s
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . .
# 3 . . X X X X X .
# 4 . . X O X X X .
# 5 . X O X X O X .
# 6 X X O O X X X .
# 7 . . X X X X . .
# 8 . . . . . O . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 23 / 59 / 767
# 白   棋: 6 / 58 / 696
#
# 请等一会，对方 白棋-O 正在思考中...
# mcts 58.00059270858765
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . .
# 3 . . X X X X X .
# 4 . . X O X X X .
# 5 . X O X X O X .
# 6 X X O O O O O O
# 7 . . X X X X . .
# 8 . . . . . O . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 20 / 59 / 767
# 白   棋: 10 / 58 / 754
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 2730	play out time: 0.02s	policy time: 0.02s	total time: 59s 9.5ms
# play out times: 2730	avg play out time: 0s 21.6ms	avg policy time: 0.02s
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . .
# 3 . . X X X X X .
# 4 . . X O X X X .
# 5 . X O X X O X X
# 6 X X O O O O X O
# 7 . . X X X X . .
# 8 . . . . . O . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 22 / 59 / 826
# 白   棋: 9 / 58 / 754
#
# 请等一会，对方 白棋-O 正在思考中...
# mcts 58.00470542907715
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . .
# 3 . . X X X X X .
# 4 . . X O O O O O
# 5 . X O X X O O O
# 6 X X O O O O X O
# 7 . . X X X X . .
# 8 . . . . . O . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 17 / 59 / 826
# 白   棋: 15 / 58 / 812
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 2863	play out time: 0.03s	policy time: 0.03s	total time: 59s 17.8ms
# play out times: 2863	avg play out time: 0s 20.6ms	avg policy time: 0.02s
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . .
# 3 . . X X X X X X
# 4 . . X O O O X O
# 5 . X O X X X O O
# 6 X X O O X O X O
# 7 . . X X X X . .
# 8 . . . . . O . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 21 / 59 / 885
# 白   棋: 12 / 58 / 812
#
# 请等一会，对方 白棋-O 正在思考中...
# mcts 58.00333571434021
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . O
# 3 . . X X X X O O
# 4 . . X O O O X O
# 5 . X O X X X O O
# 6 X X O O X O X O
# 7 . . X X X X . .
# 8 . . . . . O . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 19 / 59 / 885
# 白   棋: 15 / 58 / 870
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 3038	play out time: 0.02s	policy time: 0.02s	total time: 59s 7.05ms
# play out times: 3038	avg play out time: 0s 19.4ms	avg policy time: 0.02s
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . O
# 3 . . X X X X O O
# 4 . X X O O O X O
# 5 . X X X X X O O
# 6 X X O X X O X O
# 7 . . X X X X . .
# 8 . . . . . O . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 22 / 59 / 944
# 白   棋: 13 / 58 / 870
#
# 请等一会，对方 白棋-O 正在思考中...
# mcts 58.001166582107544
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . O
# 3 . . X X X X O O
# 4 . X X O O O X O
# 5 . X X X X O O O
# 6 X X O X X O O O
# 7 . . X X X X . O
# 8 . . . . . O . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 20 / 59 / 944
# 白   棋: 16 / 58 / 928
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 3415	play out time: 0.01s	policy time: 0.01s	total time: 59s 9.11ms
# play out times: 3415	avg play out time: 0s 17.3ms	avg policy time: 0.02s
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . O
# 3 . . X X X X O O
# 4 . X X O O O X O
# 5 . X X X X O X O
# 6 X X O X X X X O
# 7 . . X X X X X O
# 8 . . . . . O . .
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 24 / 59 / 1003
# 白   棋: 13 / 58 / 928
#
# 请等一会，对方 白棋-O 正在思考中...
# mcts 58.00196123123169
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . O
# 3 . . X X X X O O
# 4 . X X O O O X O
# 5 . X X X O O X O
# 6 X X O X X O X O
# 7 . . X X X X O O
# 8 . . . . . O . O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 21 / 59 / 1003
# 白   棋: 17 / 58 / 986
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 3637	play out time: 0.01s	policy time: 0.01s	total time: 59s 9.24ms
# play out times: 3637	avg play out time: 0s 16.2ms	avg policy time: 0.02s
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . O
# 3 . . X X X X O O
# 4 . X X O O O X O
# 5 . X X X O O X O
# 6 X X O X X O X O
# 7 . . X X X X X O
# 8 . . . . . O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 23 / 59 / 1062
# 白   棋: 16 / 58 / 986
#
# 请等一会，对方 白棋-O 正在思考中...
# mcts 58.00286054611206
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . O
# 3 . . X X X X O O
# 4 . X X O O O X O
# 5 . X X X O O X O
# 6 X X O X O O O O
# 7 . . X O O O X O
# 8 . . . . O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 18 / 59 / 1062
# 白   棋: 22 / 58 / 1044
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 4196	play out time: 0.02s	policy time: 0.01s	total time: 59s 7.71ms
# play out times: 4196	avg play out time: 0s 14.1ms	avg policy time: 0.01s
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . O
# 3 . . X X X X O O
# 4 . X X O O O X O
# 5 . X X X O X X O
# 6 X X O X X O O O
# 7 . . X X O O X O
# 8 . . X . O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 22 / 59 / 1121
# 白   棋: 19 / 58 / 1044
#
# 请等一会，对方 白棋-O 正在思考中...
# mcts 58.00284552574158
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . . O
# 3 . . X X X X O O
# 4 . X X O O O X O
# 5 . X X O O X X O
# 6 X X O O X O O O
# 7 . . X O O O X O
# 8 . . X O O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 19 / 59 / 1121
# 白   棋: 23 / 58 / 1102
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 5196	play out time: 0.02s	policy time: 0.02s	total time: 59s 4.21ms
# play out times: 5196	avg play out time: 0s 11.4ms	avg policy time: 0.01s
#   A B C D E F G H
# 1 . . . . . . . .
# 2 . . X . . . X O
# 3 . . X X X X X O
# 4 . X X O O O X O
# 5 . X X O O X X O
# 6 X X O O X O O O
# 7 . . X O O O X O
# 8 . . X O O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 21 / 59 / 1180
# 白   棋: 22 / 58 / 1102
#
# 请等一会，对方 白棋-O 正在思考中...
# mcts 58.00086736679077
#   A B C D E F G H
# 1 . . . . . . . O
# 2 . . X . . . O O
# 3 . . X X X O X O
# 4 . X X O O O X O
# 5 . X X O O X X O
# 6 X X O O X O O O
# 7 . . X O O O X O
# 8 . . X O O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 19 / 59 / 1180
# 白   棋: 25 / 58 / 1160
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 5829	play out time: 0.01s	policy time: 0.01s	total time: 59s 7.51ms
# play out times: 5829	avg play out time: 0s 10.1ms	avg policy time: 0.01s
#   A B C D E F G H
# 1 . . . . . . . O
# 2 . . X . X . O O
# 3 . . X X X X X O
# 4 . X X O O O X O
# 5 . X X O O X X O
# 6 X X O O X O O O
# 7 . . X O O O X O
# 8 . . X O O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 21 / 59 / 1239
# 白   棋: 24 / 58 / 1160
#
# 请等一会，对方 白棋-O 正在思考中...
# mcts 58.00201082229614
#   A B C D E F G H
# 1 . . . . . . . O
# 2 . . X . X O O O
# 3 . . X X O O O O
# 4 . X X O O O X O
# 5 . X X O O X X O
# 6 X X O O X O O O
# 7 . . X O O O X O
# 8 . . X O O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 18 / 59 / 1239
# 白   棋: 28 / 58 / 1218
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 6489	play out time: 0.01s	policy time: 0.01s	total time: 59s 3.62ms
# play out times: 6489	avg play out time: 0s 9.09ms	avg policy time: 0.01s
#   A B C D E F G H
# 1 . . . . . . . O
# 2 . . X X X O O O
# 3 . . X X X O O O
# 4 . X X O O X X O
# 5 . X X O O X X O
# 6 X X O O X O O O
# 7 . . X O O O X O
# 8 . . X O O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 21 / 59 / 1298
# 白   棋: 26 / 58 / 1218
#
# 请等一会，对方 白棋-O 正在思考中...
# mcts 58.000582218170166
#   A B C D E F G H
# 1 . . . . . . . O
# 2 . . X X X O O O
# 3 O . X X X O O O
# 4 . O X O O X X O
# 5 . X O O O X X O
# 6 X X O O X O O O
# 7 . . X O O O X O
# 8 . . X O O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 19 / 59 / 1298
# 白   棋: 29 / 58 / 1276
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 7753	play out time: 0.01s	policy time: 0.01s	total time: 59s 3.75ms
# play out times: 7753	avg play out time: 0s 7.61ms	avg policy time: 0.01s
#   A B C D E F G H
# 1 . . . . . . . O
# 2 . . X X X O O O
# 3 O X X X X O O O
# 4 . X X O O X X O
# 5 . X O O O X X O
# 6 X X O O X O O O
# 7 . . X O O O X O
# 8 . . X O O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 21 / 59 / 1357
# 白   棋: 28 / 58 / 1276
#
# 请等一会，对方 白棋-O 正在思考中...
# mcts 58.00113129615784
#   A B C D E F G H
# 1 . . . . O . . O
# 2 . . X X O O O O
# 3 O X X X O O O O
# 4 . X X O O X X O
# 5 . X O O O X X O
# 6 X X O O X O O O
# 7 . . X O O O X O
# 8 . . X O O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 19 / 59 / 1357
# 白   棋: 31 / 58 / 1334
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 11901	play out time: 0.01s	policy time: 0.00s	total time: 59s 4.67ms
# play out times: 11901	avg play out time: 0s 4.96ms	avg policy time: 0.00s
#   A B C D E F G H
# 1 . . . X O . . O
# 2 . . X X X O O O
# 3 O X X X O X O O
# 4 . X X O O X X O
# 5 . X O O O X X O
# 6 X X O O X O O O
# 7 . . X O O O X O
# 8 . . X O O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 22 / 59 / 1416
# 白   棋: 29 / 58 / 1334
#
# 请等一会，对方 白棋-O 正在思考中...
# 请等一会，对方 白棋-O 正在思考中...
# alpha beta 58.000837564468384
#   A B C D E F G H
# 1 . . O O O . . O
# 2 . . O O X O O O
# 3 O X O X O X O O
# 4 . X O O O X X O
# 5 . X O O O X X O
# 6 X X O O X O O O
# 7 . . X O O O X O
# 8 . . X O O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 17 / 59 / 1416
# 白   棋: 35 / 58 / 1392
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 18490	play out time: 0.00s	policy time: 0.00s	total time: 59s 0.025ms
# play out times: 18490	avg play out time: 0s 3.19ms	avg policy time: 0.00s
#   A B C D E F G H
# 1 . . O O O X . O
# 2 . . O O X X O O
# 3 O X O X O X O O
# 4 . X O O O X X O
# 5 . X O O O X X O
# 6 X X O O X O O O
# 7 . . X O O O X O
# 8 . . X O O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 19 / 59 / 1475
# 白   棋: 34 / 58 / 1392
#
# 请等一会，对方 白棋-O 正在思考中...
# 请等一会，对方 白棋-O 正在思考中...
# alpha beta 7.5780298709869385
#   A B C D E F G H
# 1 . . O O O O O O
# 2 . . O O X O O O
# 3 O X O X O X O O
# 4 . X O O O X X O
# 5 . X O O O X X O
# 6 X X O O X O O O
# 7 . . X O O O X O
# 8 . . X O O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 17 / 59 / 1475
# 白   棋: 37 / 7 / 1399
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 57292	play out time: 0.00s	policy time: 0.00s	total time: 59s 1.34ms
# play out times: 57292	avg play out time: 0s 1.03ms	avg policy time: 0.00s
#   A B C D E F G H
# 1 . X O O O O O O
# 2 . . X O X O O O
# 3 O X O X O X O O
# 4 . X O O O X X O
# 5 . X O O O X X O
# 6 X X O O X O O O
# 7 . . X O O O X O
# 8 . . X O O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 19 / 59 / 1534
# 白   棋: 36 / 7 / 1399
#
# 请等一会，对方 白棋-O 正在思考中...
# 请等一会，对方 白棋-O 正在思考中...
# alpha beta 1.0821824073791504
#   A B C D E F G H
# 1 O O O O O O O O
# 2 . . X O X O O O
# 3 O X O X O X O O
# 4 . X O O O X X O
# 5 . X O O O X X O
# 6 X X O O X O O O
# 7 . . X O O O X O
# 8 . . X O O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 18 / 59 / 1534
# 白   棋: 38 / 1 / 1400
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 115352	play out time: 0.00s	policy time: 0.00s	total time: 59s 0.021ms
# play out times: 115352	avg play out time: 0s 0.511ms	avg policy time: 0.00s
#   A B C D E F G H
# 1 O O O O O O O O
# 2 . X X O X O O O
# 3 O X X X O X O O
# 4 . X O X O X X O
# 5 . X O O X X X O
# 6 X X O O X X O O
# 7 . . X O O O X O
# 8 . . X O O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 23 / 59 / 1593
# 白   棋: 34 / 1 / 1400
#
# 请等一会，对方 白棋-O 正在思考中...
# 请等一会，对方 白棋-O 正在思考中...
# alpha beta 0.08096694946289062
#   A B C D E F G H
# 1 O O O O O O O O
# 2 O O O O X O O O
# 3 O O X X O X O O
# 4 . X O X O X X O
# 5 . X O O X X X O
# 6 X X O O X X O O
# 7 . . X O O O X O
# 8 . . X O O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 20 / 59 / 1593
# 白   棋: 38 / 0 / 1400
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 144093	play out time: 0.00s	policy time: 0.00s	total time: 59s 0.196ms
# play out times: 144093	avg play out time: 0s 0.409ms	avg policy time: 0.00s
#   A B C D E F G H
# 1 O O O O O O O O
# 2 O O O O X O O O
# 3 O O X X O X O O
# 4 . X O X X X X O
# 5 . X O X X X X O
# 6 X X X O X X O O
# 7 . X X O O O X O
# 8 . . X O O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 24 / 59 / 1652
# 白   棋: 35 / 0 / 1400
#
# 请等一会，对方 白棋-O 正在思考中...
# 请等一会，对方 白棋-O 正在思考中...
# alpha beta 0.025099515914916992
#   A B C D E F G H
# 1 O O O O O O O O
# 2 O O O O X O O O
# 3 O O X X O O O O
# 4 . X O X O X X O
# 5 . X O O X X X O
# 6 X X O O X X O O
# 7 . O X O O O X O
# 8 O . X O O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 19 / 59 / 1652
# 白   棋: 41 / 0 / 1400
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 165929	play out time: 0.01s	policy time: 0.00s	total time: 59s 1.2ms
# play out times: 165929	avg play out time: 0s 0.356ms	avg policy time: 0.00s
#   A B C D E F G H
# 1 O O O O O O O O
# 2 O O O O X O O O
# 3 O O X X O O O O
# 4 . X O X O X X O
# 5 . X O O X X X O
# 6 X X O O X X O O
# 7 . X X O O O X O
# 8 O X X O O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 21 / 59 / 1711
# 白   棋: 40 / 0 / 1400
#
# 请等一会，对方 白棋-O 正在思考中...
# 请等一会，对方 白棋-O 正在思考中...
# alpha beta 0.0032033920288085938
#   A B C D E F G H
# 1 O O O O O O O O
# 2 O O O O X O O O
# 3 O O X X O O O O
# 4 O O O X O X X O
# 5 . O O O X X X O
# 6 X X O O X X O O
# 7 . X X O O O X O
# 8 O X X O O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 19 / 59 / 1711
# 白   棋: 43 / 0 / 1400
#
# 请等一会，对方 黑棋-X 正在思考中...
# play out: 190064	play out time: 0.00s	policy time: 0.00s	total time: 59s 0.048ms
# play out times: 190064	avg play out time: 0s 0.31ms	avg policy time: 0.00s
#   A B C D E F G H
# 1 O O O O O O O O
# 2 O O O O X O O O
# 3 O O X X O O O O
# 4 O X O X O X X O
# 5 X X X X X X X O
# 6 X X O O X X O O
# 7 . X X O O O X O
# 8 O X X O O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 24 / 59 / 1770
# 白   棋: 39 / 0 / 1400
#
# 请等一会，对方 白棋-O 正在思考中...
# 请等一会，对方 白棋-O 正在思考中...
# alpha beta 0.00036716461181640625
#   A B C D E F G H
# 1 O O O O O O O O
# 2 O O O O X O O O
# 3 O O X X O O O O
# 4 O X O O O X X O
# 5 O X O X X X X O
# 6 O O O O X X O O
# 7 O O O O O O X O
# 8 O X X O O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 17 / 59 / 1770
# 白   棋: 47 / 0 / 1400
#
#
# =====游戏结束!=====
#
#   A B C D E F G H
# 1 O O O O O O O O
# 2 O O O O X O O O
# 3 O O X X O O O O
# 4 O X O O O X X O
# 5 O X O X X X X O
# 6 O O O O X X O O
# 7 O O O O O O X O
# 8 O X X O O O X O
# 统计棋局: 棋子总数 / 每一步耗时 / 总时间
# 黑   棋: 17 / 59 / 1770
# 白   棋: 47 / 0 / 1400
#
# 白棋获胜!
# ('white_win', 30)
